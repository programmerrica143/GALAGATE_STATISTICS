# %%
lib = ["numpy", "pandas", "matplotlib", "scipy", "stats", "statsmodels"]

for pkg in lib:
    print(f"Checking installation for {pkg}...")
    # !pip list | findstr {pkg}
# Out:
# Checking installation for numpy...
# numpy                             2.1.3Checking installation for pandas...
#
# numpydoc                          1.7.0
# pandas                            2.2.3
# Checking installation for matplotlib...
# matplotlib                        3.10.0
# matplotlib-inline                 0.1.6
# Checking installation for scipy...
# scipy                             1.15.3
# Checking installation for stats...
# statsmodels                       0.14.4
# Checking installation for statsmodels...
# statsmodels                       0.14.4
